# %%
import af2genomics

# %%
af2genomics.query_missense(['P09874/S568F', 'P09874/D678H'])
# Out:
#      variant_id  ESM1b_LLR ESM1b_is_pathogenic  am_pathogenicity    am_class  \
# 0  P09874/D678H    -11.783          pathogenic            0.9286  pathogenic
# 1  P09874/S568F    -14.022          pathogenic            0.9982  pathogenic
#
#         eve  pred_ddg  plddt  sasa  pocketscore  pocketrank  interface  \
# 0  0.848019   3.79725  87.95  47.0   -99.000000       -99.0      -99.0
# 1  0.836610   6.84845  93.05  13.0    76.229073         3.0      -99.0
#
#    interface_strict  freq xref significance association  clintype
# 0             -99.0 -99.0  UNK          UNK         UNK       2.0
# 1             -99.0 -99.0  UNK          UNK         UNK       2.0
