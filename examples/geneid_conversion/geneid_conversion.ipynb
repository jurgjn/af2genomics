# %%
from af2genomics import *
# Out:
# prody not found; if needed, install with: conda install conda-forge::prody

# %%
# Convert gene name to entrez id (used on depmap.org)
g_convert(['CASQ2', 'CASQ1', 'GSTO1', 'DMD', 'GSTM2'], target='ENTREZGENE_ACC')
# Out:
#   converted                                        description incoming  \
# 0       845  calsequestrin 2 [Source:HGNC Symbol;Acc:HGNC:1...    CASQ2
# 1       844  calsequestrin 1 [Source:HGNC Symbol;Acc:HGNC:1...    CASQ1
# 2      9446  glutathione S-transferase omega 1 [Source:HGNC...    GSTO1
# 3      1756      dystrophin [Source:HGNC Symbol;Acc:HGNC:2928]      DMD
# 4      2946  glutathione S-transferase mu 2 [Source:HGNC Sy...    GSTM2
#
#    n_converted  n_incoming   name  \
# 0            1           1  CASQ2
# 1            1           2  CASQ1
# 2            1           3  GSTO1
# 3            1           4    DMD
# 4            1           5  GSTM2
#
#                                       namespaces    query
# 0  ENTREZGENE,GENECARDS,HGNC,UNIPROT_GN,WIKIGENE  query_1
# 1  ENTREZGENE,GENECARDS,HGNC,UNIPROT_GN,WIKIGENE  query_1
# 2  ENTREZGENE,GENECARDS,HGNC,UNIPROT_GN,WIKIGENE  query_1
# 3  ENTREZGENE,GENECARDS,HGNC,UNIPROT_GN,WIKIGENE  query_1
# ...

# %%
# Convert gene name to UniProt canonical id (used in https://alphafold.ebi.ac.uk)
g_convert(['CASQ2', 'CASQ1', 'GSTO1', 'DMD', 'GSTM2'], target='UNIPROTSWISSPROT_ACC')
# Out:
#   converted                                        description incoming  \
# 0    O14958  calsequestrin 2 [Source:HGNC Symbol;Acc:HGNC:1...    CASQ2
# 1    P31415  calsequestrin 1 [Source:HGNC Symbol;Acc:HGNC:1...    CASQ1
# 2    P78417  glutathione S-transferase omega 1 [Source:HGNC...    GSTO1
# 3    P11532      dystrophin [Source:HGNC Symbol;Acc:HGNC:2928]      DMD
# 4    P28161  glutathione S-transferase mu 2 [Source:HGNC Sy...    GSTM2
#
#    n_converted  n_incoming   name  \
# 0            1           1  CASQ2
# 1            1           2  CASQ1
# 2            1           3  GSTO1
# 3            1           4    DMD
# 4            1           5  GSTM2
#
#                                       namespaces    query
# 0  ENTREZGENE,GENECARDS,HGNC,UNIPROT_GN,WIKIGENE  query_1
# 1  ENTREZGENE,GENECARDS,HGNC,UNIPROT_GN,WIKIGENE  query_1
# 2  ENTREZGENE,GENECARDS,HGNC,UNIPROT_GN,WIKIGENE  query_1
# 3  ENTREZGENE,GENECARDS,HGNC,UNIPROT_GN,WIKIGENE  query_1
# ...
