# %%
# Adapted OpenFold installation instructions from: https://openfold.readthedocs.io/en/latest/Installation.html
# Commands should run <30min on an interactive node with a GPU, e.g.: srun -J pty-$(hostname) --ntasks=10 --mem-per-cpu=10G --time=1-0 --gpus=rtx_4090:1 --gres=gpumem:16g --tmp=16384 --pty bash -l
module load eth_proxy
module load stack/2024-05
module load cuda/12.2.1
# Out:
# Many modules are hidden in this stack. Use "module --show_hidden spider SOFTWARE" if you are not able to find the required software

# %%
# 1. Clone & checkout pl_upgrades branch for CUDA12 support
git clone https://github.com/aqlaboratory/openfold.git
cd openfold
git checkout pl_upgrades
# Out:
# Cloning into 'openfold'...
# remote: Enumerating objects: 7810, done.
# remote: Counting objects: 100% (3541/3541), done.
# remote: Compressing objects: 100% (925/925), done.
# remote: Total 7810 (delta 2834), reused 3059 (delta 2613), pack-reused 4269
# Receiving objects: 100% (7810/7810), 19.46 MiB | 27.64 MiB/s, done.
# Resolving deltas: 100% (5508/5508), done.
# Updating files: 100% (232/232), done.
# Branch 'pl_upgrades' set up to track remote branch 'pl_upgrades' from 'origin'.
# Switched to a new branch 'pl_upgrades'

# %%
# Check out CUTLASS code from the third-party dependancies script (scripts/install_third_party_dependencies.sh); needed for setting openfold_env (step 2)
echo "Download CUTLASS, required for Deepspeed Evoformer attention kernel"
git clone https://github.com/NVIDIA/cutlass --depth 1
# Out:
# Download CUTLASS, required for Deepspeed Evoformer attention kernel
# Cloning into 'cutlass'...
# remote: Enumerating objects: 5992, done.
# remote: Counting objects: 100% (5992/5992), done.
# remote: Compressing objects: 100% (1639/1639), done.
# remote: Total 5992 (delta 3485), reused 4940 (delta 3065), pack-reused 0
# Receiving objects: 100% (5992/5992), 27.23 MiB | 26.01 MiB/s, done.
# Resolving deltas: 100% (3485/3485), done.
# Updating files: 100% (5774/5774), done.

# %%
# 2. Create openfold_env environment, adapted from: https://github.com/aqlaboratory/openfold/blob/pl_upgrades/environment.yml
echo 'Changes from baseline:'
diff ../../workflow/envs/openfold-eu.yaml environment.yml
echo 'Attempting to install:'
mamba env create -n openfold_env -y -q -f ../../workflow/envs/openfold-eu.yaml
# Out:
# Changes from baseline:
# 9,11d8
# <   - gcc_linux-64<13
# <   - gxx_linux-64<13
# <   - cudatoolkit-dev
# 19c16
# <   - numpy<2 # Fix: A module that was compiled using NumPy 1.x cannot be run in NumPy 2.0.0 as it may crash. /../ If you are a user of the module, the easiest solution will be to downgrade to 'numpy<2' or try to upgrade the affected module.
# ---
# >   - numpy
# Attempting to install:
# Channels:
#  - conda-forge
#  - bioconda
#  - pytorch
#  - nvidia
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... By downloading and using the CUDA Toolkit conda packages, you accept the terms and conditions of the CUDA End User License Agreement (EULA): https://docs.nvidia.com/cuda/eula/index.html
#
# done
# Installing pip dependencies: ...working... done

# %%
# 2b. Activate the environment & set up variables: https://conda.io/projects/conda/en/latest/user-guide/tasks/manage-environments.html#macos-and-linux
conda activate openfold_env
cd $CONDA_PREFIX
mkdir -p ./etc/conda/activate.d
mkdir -p ./etc/conda/deactivate.d

cat << EOF > ./etc/conda/activate.d/env_vars.sh
#!/bin/sh
export LIBRARY_PATH=$CONDA_PREFIX/lib:$LIBRARY_PATH
export LD_LIBRARY_PATH=$CONDA_PREFIX/lib:$LD_LIBRARY_PATH
export MAX_JOBS=$SLURM_NTASKS
EOF

cat << EOF > ./etc/conda/deactivate.d/env_vars.sh
#!/bin/sh
unset LIBRARY_PATH
unset LD_LIBRARY_PATH
unset MAX_JOBS
EOF

cd -
conda deactivate
# Out:
# (openfold_env)
# (openfold_env)
# (openfold_env)
# (openfold_env)
# (openfold_env)
# (openfold_env)
# (openfold_env)
# (openfold_env)
# (openfold_env)
# /cluster/work/beltrao/jjaenes/24.06.10_af2genomics/software/openfold
# (openfold_env)
# (miniconda3)

# %%
# 3. Run (the remainder of) the third-party dependancies script: https://github.com/aqlaboratory/openfold/blob/pl_upgrades/scripts/install_third_party_dependencies.sh
conda activate openfold_env
# Download folding resources
wget -N --no-check-certificate -P openfold/resources \
    https://git.scicore.unibas.ch/schwede/openstructure/-/raw/7102c63615b64735c4941278d92b554ec94415f8/modules/mol/alg/src/stereo_chemical_props.txt

# Certain tests need access to this file
mkdir -p tests/test_data/alphafold/common
ln -rs openfold/resources/stereo_chemical_props.txt tests/test_data/alphafold/common

# Decompress test data
gunzip -c tests/test_data/sample_feats.pickle.gz > tests/test_data/sample_feats.pickle

python setup.py install

# (Already run before..)
#echo "Download CUTLASS, required for Deepspeed Evoformer attention kernel"
#git clone https://github.com/NVIDIA/cutlass --depth 1
conda env config vars set CUTLASS_PATH=$PWD/cutlass

# This setting is used to fix a worker assignment issue during data loading
conda env config vars set KMP_AFFINITY=none
conda deactivate
# Out:
# (miniconda3)
# (openfold_env)
# (openfold_env)
# --2024-06-21 15:27:42--  https://git.scicore.unibas.ch/schwede/openstructure/-/raw/7102c63615b64735c4941278d92b554ec94415f8/modules/mol/alg/src/stereo_chemical_props.txt
# Resolving proxy.ethz.ch (proxy.ethz.ch)... 129.132.202.155
# Connecting to proxy.ethz.ch (proxy.ethz.ch)|129.132.202.155|:3128... connected.
# Proxy request sent, awaiting response... 200 OK
# Length: 9119 (8.9K) [text/plain]
# Saving to: ‘openfold/resources/stereo_chemical_props.txt’
#
# stereo_chemical_pro 100%[===================>]   8.91K  --.-KB/s    in 0.01s
#
# Last-modified header missing -- time-stamps turned off.
# 2024-06-21 15:27:42 (869 KB/s) - ‘openfold/resources/stereo_chemical_props.txt’ saved [9119/9119]
#
# (openfold_env)
# (openfold_env)
# (openfold_env)
# (openfold_env)
# (openfold_env)
# (openfold_env)
# (openfold_env)
# (openfold_env)
# (openfold_env)
# running install
# /cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/lib/python3.10/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# /cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/lib/python3.10/site-packages/setuptools/command/easy_install.py:156: EasyInstallDeprecationWarning: easy_install command is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# running bdist_egg
# running egg_info
# creating openfold.egg-info
# writing openfold.egg-info/PKG-INFO
# writing dependency_links to openfold.egg-info/dependency_links.txt
# writing top-level names to openfold.egg-info/top_level.txt
# writing manifest file 'openfold.egg-info/SOURCES.txt'
# reading manifest file 'openfold.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'openfold.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib.linux-x86_64-3.10
# creating build/lib.linux-x86_64-3.10/openfold
# copying openfold/config.py -> build/lib.linux-x86_64-3.10/openfold
# copying openfold/__init__.py -> build/lib.linux-x86_64-3.10/openfold
# creating build/lib.linux-x86_64-3.10/openfold/np
# copying openfold/np/residue_constants.py -> build/lib.linux-x86_64-3.10/openfold/np
# copying openfold/np/protein.py -> build/lib.linux-x86_64-3.10/openfold/np
# copying openfold/np/__init__.py -> build/lib.linux-x86_64-3.10/openfold/np
# creating build/lib.linux-x86_64-3.10/openfold/model
# copying openfold/model/primitives.py -> build/lib.linux-x86_64-3.10/openfold/model
# copying openfold/model/dropout.py -> build/lib.linux-x86_64-3.10/openfold/model
# copying openfold/model/embedders.py -> build/lib.linux-x86_64-3.10/openfold/model
# copying openfold/model/outer_product_mean.py -> build/lib.linux-x86_64-3.10/openfold/model
# copying openfold/model/triangular_multiplicative_update.py -> build/lib.linux-x86_64-3.10/openfold/model
# copying openfold/model/msa.py -> build/lib.linux-x86_64-3.10/openfold/model
# copying openfold/model/evoformer.py -> build/lib.linux-x86_64-3.10/openfold/model
# copying openfold/model/torchscript.py -> build/lib.linux-x86_64-3.10/openfold/model
# copying openfold/model/__init__.py -> build/lib.linux-x86_64-3.10/openfold/model
# copying openfold/model/triangular_attention.py -> build/lib.linux-x86_64-3.10/openfold/model
# copying openfold/model/pair_transition.py -> build/lib.linux-x86_64-3.10/openfold/model
# copying openfold/model/structure_module.py -> build/lib.linux-x86_64-3.10/openfold/model
# copying openfold/model/heads.py -> build/lib.linux-x86_64-3.10/openfold/model
# copying openfold/model/template.py -> build/lib.linux-x86_64-3.10/openfold/model
# copying openfold/model/model.py -> build/lib.linux-x86_64-3.10/openfold/model
# creating build/lib.linux-x86_64-3.10/openfold/data
# copying openfold/data/data_pipeline.py -> build/lib.linux-x86_64-3.10/openfold/data
# copying openfold/data/data_modules.py -> build/lib.linux-x86_64-3.10/openfold/data
# copying openfold/data/msa_pairing.py -> build/lib.linux-x86_64-3.10/openfold/data
# copying openfold/data/feature_pipeline.py -> build/lib.linux-x86_64-3.10/openfold/data
# copying openfold/data/data_transforms_multimer.py -> build/lib.linux-x86_64-3.10/openfold/data
# copying openfold/data/msa_identifiers.py -> build/lib.linux-x86_64-3.10/openfold/data
# copying openfold/data/parsers.py -> build/lib.linux-x86_64-3.10/openfold/data
# copying openfold/data/errors.py -> build/lib.linux-x86_64-3.10/openfold/data
# copying openfold/data/input_pipeline_multimer.py -> build/lib.linux-x86_64-3.10/openfold/data
# copying openfold/data/input_pipeline.py -> build/lib.linux-x86_64-3.10/openfold/data
# copying openfold/data/templates.py -> build/lib.linux-x86_64-3.10/openfold/data
# copying openfold/data/data_transforms.py -> build/lib.linux-x86_64-3.10/openfold/data
# copying openfold/data/__init__.py -> build/lib.linux-x86_64-3.10/openfold/data
# copying openfold/data/feature_processing_multimer.py -> build/lib.linux-x86_64-3.10/openfold/data
# copying openfold/data/mmcif_parsing.py -> build/lib.linux-x86_64-3.10/openfold/data
# creating build/lib.linux-x86_64-3.10/openfold/utils
# copying openfold/utils/all_atom_multimer.py -> build/lib.linux-x86_64-3.10/openfold/utils
# copying openfold/utils/logger.py -> build/lib.linux-x86_64-3.10/openfold/utils
# copying openfold/utils/checkpointing.py -> build/lib.linux-x86_64-3.10/openfold/utils
# copying openfold/utils/script_utils.py -> build/lib.linux-x86_64-3.10/openfold/utils
# copying openfold/utils/import_weights.py -> build/lib.linux-x86_64-3.10/openfold/utils
# copying openfold/utils/callbacks.py -> build/lib.linux-x86_64-3.10/openfold/utils
# copying openfold/utils/feats.py -> build/lib.linux-x86_64-3.10/openfold/utils
# copying openfold/utils/rigid_utils.py -> build/lib.linux-x86_64-3.10/openfold/utils
# copying openfold/utils/trace_utils.py -> build/lib.linux-x86_64-3.10/openfold/utils
# copying openfold/utils/tensor_utils.py -> build/lib.linux-x86_64-3.10/openfold/utils
# copying openfold/utils/chunk_utils.py -> build/lib.linux-x86_64-3.10/openfold/utils
# copying openfold/utils/multi_chain_permutation.py -> build/lib.linux-x86_64-3.10/openfold/utils
# copying openfold/utils/__init__.py -> build/lib.linux-x86_64-3.10/openfold/utils
# copying openfold/utils/validation_metrics.py -> build/lib.linux-x86_64-3.10/openfold/utils
# copying openfold/utils/precision_utils.py -> build/lib.linux-x86_64-3.10/openfold/utils
# copying openfold/utils/superimposition.py -> build/lib.linux-x86_64-3.10/openfold/utils
# copying openfold/utils/argparse_utils.py -> build/lib.linux-x86_64-3.10/openfold/utils
# copying openfold/utils/loss.py -> build/lib.linux-x86_64-3.10/openfold/utils
# copying openfold/utils/exponential_moving_average.py -> build/lib.linux-x86_64-3.10/openfold/utils
# copying openfold/utils/lr_schedulers.py -> build/lib.linux-x86_64-3.10/openfold/utils
# creating build/lib.linux-x86_64-3.10/openfold/resources
# copying openfold/resources/__init__.py -> build/lib.linux-x86_64-3.10/openfold/resources
# creating build/lib.linux-x86_64-3.10/openfold/np/relax
# copying openfold/np/relax/relax.py -> build/lib.linux-x86_64-3.10/openfold/np/relax
# copying openfold/np/relax/__init__.py -> build/lib.linux-x86_64-3.10/openfold/np/relax
# copying openfold/np/relax/amber_minimize.py -> build/lib.linux-x86_64-3.10/openfold/np/relax
# copying openfold/np/relax/cleanup.py -> build/lib.linux-x86_64-3.10/openfold/np/relax
# copying openfold/np/relax/utils.py -> build/lib.linux-x86_64-3.10/openfold/np/relax
# creating build/lib.linux-x86_64-3.10/openfold/data/tools
# copying openfold/data/tools/kalign.py -> build/lib.linux-x86_64-3.10/openfold/data/tools
# copying openfold/data/tools/hmmbuild.py -> build/lib.linux-x86_64-3.10/openfold/data/tools
# copying openfold/data/tools/parse_msa_files.py -> build/lib.linux-x86_64-3.10/openfold/data/tools
# copying openfold/data/tools/__init__.py -> build/lib.linux-x86_64-3.10/openfold/data/tools
# copying openfold/data/tools/hhsearch.py -> build/lib.linux-x86_64-3.10/openfold/data/tools
# copying openfold/data/tools/hmmsearch.py -> build/lib.linux-x86_64-3.10/openfold/data/tools
# copying openfold/data/tools/hhblits.py -> build/lib.linux-x86_64-3.10/openfold/data/tools
# copying openfold/data/tools/utils.py -> build/lib.linux-x86_64-3.10/openfold/data/tools
# copying openfold/data/tools/jackhmmer.py -> build/lib.linux-x86_64-3.10/openfold/data/tools
# creating build/lib.linux-x86_64-3.10/openfold/utils/geometry
# copying openfold/utils/geometry/quat_rigid.py -> build/lib.linux-x86_64-3.10/openfold/utils/geometry
# copying openfold/utils/geometry/__init__.py -> build/lib.linux-x86_64-3.10/openfold/utils/geometry
# copying openfold/utils/geometry/vector.py -> build/lib.linux-x86_64-3.10/openfold/utils/geometry
# copying openfold/utils/geometry/utils.py -> build/lib.linux-x86_64-3.10/openfold/utils/geometry
# copying openfold/utils/geometry/test_utils.py -> build/lib.linux-x86_64-3.10/openfold/utils/geometry
# copying openfold/utils/geometry/rotation_matrix.py -> build/lib.linux-x86_64-3.10/openfold/utils/geometry
# copying openfold/utils/geometry/rigid_matrix_vector.py -> build/lib.linux-x86_64-3.10/openfold/utils/geometry
# creating build/lib.linux-x86_64-3.10/openfold/utils/kernel
# copying openfold/utils/kernel/attention_core.py -> build/lib.linux-x86_64-3.10/openfold/utils/kernel
# copying openfold/utils/kernel/__init__.py -> build/lib.linux-x86_64-3.10/openfold/utils/kernel
# copying openfold/resources/stereo_chemical_props.txt -> build/lib.linux-x86_64-3.10/openfold/resources
# creating build/lib.linux-x86_64-3.10/openfold/utils/kernel/csrc
# copying openfold/utils/kernel/csrc/softmax_cuda_kernel.cu -> build/lib.linux-x86_64-3.10/openfold/utils/kernel/csrc
# copying openfold/utils/kernel/csrc/softmax_cuda.cpp -> build/lib.linux-x86_64-3.10/openfold/utils/kernel/csrc
# copying openfold/utils/kernel/csrc/softmax_cuda_stub.cpp -> build/lib.linux-x86_64-3.10/openfold/utils/kernel/csrc
# copying openfold/utils/kernel/csrc/compat.h -> build/lib.linux-x86_64-3.10/openfold/utils/kernel/csrc
# running build_ext
# /cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/lib/python3.10/site-packages/torch/utils/cpp_extension.py:414: UserWarning: The detected CUDA version (12.2) has a minor version mismatch with the version that was used to compile PyTorch (12.1). Most likely this shouldn't be a problem.
#   warnings.warn(CUDA_MISMATCH_WARN.format(cuda_str_version, torch.version.cuda))
# /cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/lib/python3.10/site-packages/torch/utils/cpp_extension.py:424: UserWarning: There are no /cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/bin/x86_64-conda-linux-gnu-c++ version bounds defined for CUDA version 12.2
#   warnings.warn(f'There are no {compiler_name} version bounds defined for CUDA version {cuda_str_version}')
# building 'attn_core_inplace_cuda' extension
# creating /cluster/work/beltrao/jjaenes/24.06.10_af2genomics/software/openfold/build/temp.linux-x86_64-3.10
# creating /cluster/work/beltrao/jjaenes/24.06.10_af2genomics/software/openfold/build/temp.linux-x86_64-3.10/openfold
# creating /cluster/work/beltrao/jjaenes/24.06.10_af2genomics/software/openfold/build/temp.linux-x86_64-3.10/openfold/utils
# creating /cluster/work/beltrao/jjaenes/24.06.10_af2genomics/software/openfold/build/temp.linux-x86_64-3.10/openfold/utils/kernel
# creating /cluster/work/beltrao/jjaenes/24.06.10_af2genomics/software/openfold/build/temp.linux-x86_64-3.10/openfold/utils/kernel/csrc
# Emitting ninja build file /cluster/work/beltrao/jjaenes/24.06.10_af2genomics/software/openfold/build/temp.linux-x86_64-3.10/build.ninja...
# Compiling objects...
# Using envvar MAX_JOBS (10) as the number of workers...
# [1/2] /cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/bin/x86_64-conda-linux-gnu-c++ -MMD -MF /cluster/work/beltrao/jjaenes/24.06.10_af2genomics/software/openfold/build/temp.linux-x86_64-3.10/openfold/utils/kernel/csrc/softmax_cuda.o.d -Wno-unused-result -Wsign-compare -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/include -fPIC -O2 -isystem /cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/include -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/include -fPIC -I/cluster/work/beltrao/jjaenes/24.06.10_af2genomics/software/openfold/openfold/utils/kernel/csrc/ -I/cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/lib/python3.10/site-packages/torch/include -I/cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/lib/python3.10/site-packages/torch/include/torch/csrc/api/include -I/cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/lib/python3.10/site-packages/torch/include/TH -I/cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/lib/python3.10/site-packages/torch/include/THC -I/cluster/software/stacks/2024-05/spack/opt/spack/linux-ubuntu22.04-x86_64_v3/gcc-13.2.0/cuda-12.2.1-fv6yilrnidoe35nh24iszjkf63bihikt/include -I/cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/include/python3.10 -c -c /cluster/work/beltrao/jjaenes/24.06.10_af2genomics/software/openfold/openfold/utils/kernel/csrc/softmax_cuda.cpp -o /cluster/work/beltrao/jjaenes/24.06.10_af2genomics/software/openfold/build/temp.linux-x86_64-3.10/openfold/utils/kernel/csrc/softmax_cuda.o -O3 -DVERSION_GE_1_1 -DVERSION_GE_1_3 -DVERSION_GE_1_5 -DTORCH_API_INCLUDE_EXTENSION_H '-DPYBIND11_COMPILER_TYPE="_gcc"' '-DPYBIND11_STDLIB="_libstdcpp"' '-DPYBIND11_BUILD_ABI="_cxxabi1011"' -DTORCH_EXTENSION_NAME=attn_core_inplace_cuda -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++17
# [2/2] /cluster/software/stacks/2024-05/spack/opt/spack/linux-ubuntu22.04-x86_64_v3/gcc-13.2.0/cuda-12.2.1-fv6yilrnidoe35nh24iszjkf63bihikt/bin/nvcc  -I/cluster/work/beltrao/jjaenes/24.06.10_af2genomics/software/openfold/openfold/utils/kernel/csrc/ -I/cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/lib/python3.10/site-packages/torch/include -I/cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/lib/python3.10/site-packages/torch/include/torch/csrc/api/include -I/cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/lib/python3.10/site-packages/torch/include/TH -I/cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/lib/python3.10/site-packages/torch/include/THC -I/cluster/software/stacks/2024-05/spack/opt/spack/linux-ubuntu22.04-x86_64_v3/gcc-13.2.0/cuda-12.2.1-fv6yilrnidoe35nh24iszjkf63bihikt/include -I/cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/include/python3.10 -c -c /cluster/work/beltrao/jjaenes/24.06.10_af2genomics/software/openfold/openfold/utils/kernel/csrc/softmax_cuda_kernel.cu -o /cluster/work/beltrao/jjaenes/24.06.10_af2genomics/software/openfold/build/temp.linux-x86_64-3.10/openfold/utils/kernel/csrc/softmax_cuda_kernel.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr --compiler-options ''"'"'-fPIC'"'"'' -O3 --use_fast_math -DVERSION_GE_1_1 -DVERSION_GE_1_3 -DVERSION_GE_1_5 -std=c++17 -maxrregcount=50 -U__CUDA_NO_HALF_OPERATORS__ -U__CUDA_NO_HALF_CONVERSIONS__ --expt-relaxed-constexpr --expt-extended-lambda -gencode arch=compute_89,code=sm_89 -DTORCH_API_INCLUDE_EXTENSION_H '-DPYBIND11_COMPILER_TYPE="_gcc"' '-DPYBIND11_STDLIB="_libstdcpp"' '-DPYBIND11_BUILD_ABI="_cxxabi1011"' -DTORCH_EXTENSION_NAME=attn_core_inplace_cuda -D_GLIBCXX_USE_CXX11_ABI=0 -ccbin /cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/bin/x86_64-conda-linux-gnu-cc
# /cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/bin/x86_64-conda-linux-gnu-c++ -shared -Wl,--allow-shlib-undefined -Wl,-rpath,/cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/lib -Wl,-rpath-link,/cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/lib -L/cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/lib -Wl,--allow-shlib-undefined -Wl,-rpath,/cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/lib -Wl,-rpath-link,/cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/lib -L/cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/lib -Wl,-O2 -Wl,--sort-common -Wl,--as-needed -Wl,-z,relro -Wl,-z,now -Wl,--disable-new-dtags -Wl,--gc-sections -Wl,--allow-shlib-undefined -Wl,-rpath,/cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/lib -Wl,-rpath-link,/cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/lib -L/cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/lib -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/include -DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/include /cluster/work/beltrao/jjaenes/24.06.10_af2genomics/software/openfold/build/temp.linux-x86_64-3.10/openfold/utils/kernel/csrc/softmax_cuda.o /cluster/work/beltrao/jjaenes/24.06.10_af2genomics/software/openfold/build/temp.linux-x86_64-3.10/openfold/utils/kernel/csrc/softmax_cuda_kernel.o -L/cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/lib/python3.10/site-packages/torch/lib -L/cluster/software/stacks/2024-05/spack/opt/spack/linux-ubuntu22.04-x86_64_v3/gcc-13.2.0/cuda-12.2.1-fv6yilrnidoe35nh24iszjkf63bihikt/lib64 -lc10 -ltorch -ltorch_cpu -ltorch_python -lcudart -lc10_cuda -ltorch_cuda -o build/lib.linux-x86_64-3.10/attn_core_inplace_cuda.cpython-310-x86_64-linux-gnu.so
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# copying build/lib.linux-x86_64-3.10/attn_core_inplace_cuda.cpython-310-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/openfold
# creating build/bdist.linux-x86_64/egg/openfold/np
# copying build/lib.linux-x86_64-3.10/openfold/np/residue_constants.py -> build/bdist.linux-x86_64/egg/openfold/np
# copying build/lib.linux-x86_64-3.10/openfold/np/protein.py -> build/bdist.linux-x86_64/egg/openfold/np
# copying build/lib.linux-x86_64-3.10/openfold/np/__init__.py -> build/bdist.linux-x86_64/egg/openfold/np
# creating build/bdist.linux-x86_64/egg/openfold/np/relax
# copying build/lib.linux-x86_64-3.10/openfold/np/relax/relax.py -> build/bdist.linux-x86_64/egg/openfold/np/relax
# copying build/lib.linux-x86_64-3.10/openfold/np/relax/__init__.py -> build/bdist.linux-x86_64/egg/openfold/np/relax
# copying build/lib.linux-x86_64-3.10/openfold/np/relax/amber_minimize.py -> build/bdist.linux-x86_64/egg/openfold/np/relax
# copying build/lib.linux-x86_64-3.10/openfold/np/relax/cleanup.py -> build/bdist.linux-x86_64/egg/openfold/np/relax
# copying build/lib.linux-x86_64-3.10/openfold/np/relax/utils.py -> build/bdist.linux-x86_64/egg/openfold/np/relax
# creating build/bdist.linux-x86_64/egg/openfold/model
# copying build/lib.linux-x86_64-3.10/openfold/model/primitives.py -> build/bdist.linux-x86_64/egg/openfold/model
# copying build/lib.linux-x86_64-3.10/openfold/model/dropout.py -> build/bdist.linux-x86_64/egg/openfold/model
# copying build/lib.linux-x86_64-3.10/openfold/model/embedders.py -> build/bdist.linux-x86_64/egg/openfold/model
# copying build/lib.linux-x86_64-3.10/openfold/model/outer_product_mean.py -> build/bdist.linux-x86_64/egg/openfold/model
# copying build/lib.linux-x86_64-3.10/openfold/model/triangular_multiplicative_update.py -> build/bdist.linux-x86_64/egg/openfold/model
# copying build/lib.linux-x86_64-3.10/openfold/model/msa.py -> build/bdist.linux-x86_64/egg/openfold/model
# copying build/lib.linux-x86_64-3.10/openfold/model/evoformer.py -> build/bdist.linux-x86_64/egg/openfold/model
# copying build/lib.linux-x86_64-3.10/openfold/model/torchscript.py -> build/bdist.linux-x86_64/egg/openfold/model
# copying build/lib.linux-x86_64-3.10/openfold/model/__init__.py -> build/bdist.linux-x86_64/egg/openfold/model
# copying build/lib.linux-x86_64-3.10/openfold/model/triangular_attention.py -> build/bdist.linux-x86_64/egg/openfold/model
# copying build/lib.linux-x86_64-3.10/openfold/model/pair_transition.py -> build/bdist.linux-x86_64/egg/openfold/model
# copying build/lib.linux-x86_64-3.10/openfold/model/structure_module.py -> build/bdist.linux-x86_64/egg/openfold/model
# copying build/lib.linux-x86_64-3.10/openfold/model/heads.py -> build/bdist.linux-x86_64/egg/openfold/model
# copying build/lib.linux-x86_64-3.10/openfold/model/template.py -> build/bdist.linux-x86_64/egg/openfold/model
# copying build/lib.linux-x86_64-3.10/openfold/model/model.py -> build/bdist.linux-x86_64/egg/openfold/model
# creating build/bdist.linux-x86_64/egg/openfold/data
# copying build/lib.linux-x86_64-3.10/openfold/data/data_pipeline.py -> build/bdist.linux-x86_64/egg/openfold/data
# creating build/bdist.linux-x86_64/egg/openfold/data/tools
# copying build/lib.linux-x86_64-3.10/openfold/data/tools/kalign.py -> build/bdist.linux-x86_64/egg/openfold/data/tools
# copying build/lib.linux-x86_64-3.10/openfold/data/tools/hmmbuild.py -> build/bdist.linux-x86_64/egg/openfold/data/tools
# copying build/lib.linux-x86_64-3.10/openfold/data/tools/parse_msa_files.py -> build/bdist.linux-x86_64/egg/openfold/data/tools
# copying build/lib.linux-x86_64-3.10/openfold/data/tools/__init__.py -> build/bdist.linux-x86_64/egg/openfold/data/tools
# copying build/lib.linux-x86_64-3.10/openfold/data/tools/hhsearch.py -> build/bdist.linux-x86_64/egg/openfold/data/tools
# copying build/lib.linux-x86_64-3.10/openfold/data/tools/hmmsearch.py -> build/bdist.linux-x86_64/egg/openfold/data/tools
# copying build/lib.linux-x86_64-3.10/openfold/data/tools/hhblits.py -> build/bdist.linux-x86_64/egg/openfold/data/tools
# copying build/lib.linux-x86_64-3.10/openfold/data/tools/utils.py -> build/bdist.linux-x86_64/egg/openfold/data/tools
# copying build/lib.linux-x86_64-3.10/openfold/data/tools/jackhmmer.py -> build/bdist.linux-x86_64/egg/openfold/data/tools
# copying build/lib.linux-x86_64-3.10/openfold/data/data_modules.py -> build/bdist.linux-x86_64/egg/openfold/data
# copying build/lib.linux-x86_64-3.10/openfold/data/msa_pairing.py -> build/bdist.linux-x86_64/egg/openfold/data
# copying build/lib.linux-x86_64-3.10/openfold/data/feature_pipeline.py -> build/bdist.linux-x86_64/egg/openfold/data
# copying build/lib.linux-x86_64-3.10/openfold/data/data_transforms_multimer.py -> build/bdist.linux-x86_64/egg/openfold/data
# copying build/lib.linux-x86_64-3.10/openfold/data/msa_identifiers.py -> build/bdist.linux-x86_64/egg/openfold/data
# copying build/lib.linux-x86_64-3.10/openfold/data/parsers.py -> build/bdist.linux-x86_64/egg/openfold/data
# copying build/lib.linux-x86_64-3.10/openfold/data/errors.py -> build/bdist.linux-x86_64/egg/openfold/data
# copying build/lib.linux-x86_64-3.10/openfold/data/input_pipeline_multimer.py -> build/bdist.linux-x86_64/egg/openfold/data
# copying build/lib.linux-x86_64-3.10/openfold/data/input_pipeline.py -> build/bdist.linux-x86_64/egg/openfold/data
# copying build/lib.linux-x86_64-3.10/openfold/data/templates.py -> build/bdist.linux-x86_64/egg/openfold/data
# copying build/lib.linux-x86_64-3.10/openfold/data/data_transforms.py -> build/bdist.linux-x86_64/egg/openfold/data
# copying build/lib.linux-x86_64-3.10/openfold/data/__init__.py -> build/bdist.linux-x86_64/egg/openfold/data
# copying build/lib.linux-x86_64-3.10/openfold/data/feature_processing_multimer.py -> build/bdist.linux-x86_64/egg/openfold/data
# copying build/lib.linux-x86_64-3.10/openfold/data/mmcif_parsing.py -> build/bdist.linux-x86_64/egg/openfold/data
# copying build/lib.linux-x86_64-3.10/openfold/config.py -> build/bdist.linux-x86_64/egg/openfold
# creating build/bdist.linux-x86_64/egg/openfold/utils
# copying build/lib.linux-x86_64-3.10/openfold/utils/all_atom_multimer.py -> build/bdist.linux-x86_64/egg/openfold/utils
# copying build/lib.linux-x86_64-3.10/openfold/utils/logger.py -> build/bdist.linux-x86_64/egg/openfold/utils
# copying build/lib.linux-x86_64-3.10/openfold/utils/checkpointing.py -> build/bdist.linux-x86_64/egg/openfold/utils
# creating build/bdist.linux-x86_64/egg/openfold/utils/geometry
# copying build/lib.linux-x86_64-3.10/openfold/utils/geometry/quat_rigid.py -> build/bdist.linux-x86_64/egg/openfold/utils/geometry
# copying build/lib.linux-x86_64-3.10/openfold/utils/geometry/__init__.py -> build/bdist.linux-x86_64/egg/openfold/utils/geometry
# copying build/lib.linux-x86_64-3.10/openfold/utils/geometry/vector.py -> build/bdist.linux-x86_64/egg/openfold/utils/geometry
# copying build/lib.linux-x86_64-3.10/openfold/utils/geometry/utils.py -> build/bdist.linux-x86_64/egg/openfold/utils/geometry
# copying build/lib.linux-x86_64-3.10/openfold/utils/geometry/test_utils.py -> build/bdist.linux-x86_64/egg/openfold/utils/geometry
# copying build/lib.linux-x86_64-3.10/openfold/utils/geometry/rotation_matrix.py -> build/bdist.linux-x86_64/egg/openfold/utils/geometry
# copying build/lib.linux-x86_64-3.10/openfold/utils/geometry/rigid_matrix_vector.py -> build/bdist.linux-x86_64/egg/openfold/utils/geometry
# copying build/lib.linux-x86_64-3.10/openfold/utils/script_utils.py -> build/bdist.linux-x86_64/egg/openfold/utils
# copying build/lib.linux-x86_64-3.10/openfold/utils/import_weights.py -> build/bdist.linux-x86_64/egg/openfold/utils
# copying build/lib.linux-x86_64-3.10/openfold/utils/callbacks.py -> build/bdist.linux-x86_64/egg/openfold/utils
# copying build/lib.linux-x86_64-3.10/openfold/utils/feats.py -> build/bdist.linux-x86_64/egg/openfold/utils
# copying build/lib.linux-x86_64-3.10/openfold/utils/rigid_utils.py -> build/bdist.linux-x86_64/egg/openfold/utils
# copying build/lib.linux-x86_64-3.10/openfold/utils/trace_utils.py -> build/bdist.linux-x86_64/egg/openfold/utils
# copying build/lib.linux-x86_64-3.10/openfold/utils/tensor_utils.py -> build/bdist.linux-x86_64/egg/openfold/utils
# copying build/lib.linux-x86_64-3.10/openfold/utils/chunk_utils.py -> build/bdist.linux-x86_64/egg/openfold/utils
# copying build/lib.linux-x86_64-3.10/openfold/utils/multi_chain_permutation.py -> build/bdist.linux-x86_64/egg/openfold/utils
# copying build/lib.linux-x86_64-3.10/openfold/utils/__init__.py -> build/bdist.linux-x86_64/egg/openfold/utils
# copying build/lib.linux-x86_64-3.10/openfold/utils/validation_metrics.py -> build/bdist.linux-x86_64/egg/openfold/utils
# copying build/lib.linux-x86_64-3.10/openfold/utils/precision_utils.py -> build/bdist.linux-x86_64/egg/openfold/utils
# copying build/lib.linux-x86_64-3.10/openfold/utils/superimposition.py -> build/bdist.linux-x86_64/egg/openfold/utils
# copying build/lib.linux-x86_64-3.10/openfold/utils/argparse_utils.py -> build/bdist.linux-x86_64/egg/openfold/utils
# creating build/bdist.linux-x86_64/egg/openfold/utils/kernel
# creating build/bdist.linux-x86_64/egg/openfold/utils/kernel/csrc
# copying build/lib.linux-x86_64-3.10/openfold/utils/kernel/csrc/softmax_cuda_kernel.cu -> build/bdist.linux-x86_64/egg/openfold/utils/kernel/csrc
# copying build/lib.linux-x86_64-3.10/openfold/utils/kernel/csrc/softmax_cuda.cpp -> build/bdist.linux-x86_64/egg/openfold/utils/kernel/csrc
# copying build/lib.linux-x86_64-3.10/openfold/utils/kernel/csrc/softmax_cuda_stub.cpp -> build/bdist.linux-x86_64/egg/openfold/utils/kernel/csrc
# copying build/lib.linux-x86_64-3.10/openfold/utils/kernel/csrc/compat.h -> build/bdist.linux-x86_64/egg/openfold/utils/kernel/csrc
# copying build/lib.linux-x86_64-3.10/openfold/utils/kernel/attention_core.py -> build/bdist.linux-x86_64/egg/openfold/utils/kernel
# copying build/lib.linux-x86_64-3.10/openfold/utils/kernel/__init__.py -> build/bdist.linux-x86_64/egg/openfold/utils/kernel
# copying build/lib.linux-x86_64-3.10/openfold/utils/loss.py -> build/bdist.linux-x86_64/egg/openfold/utils
# copying build/lib.linux-x86_64-3.10/openfold/utils/exponential_moving_average.py -> build/bdist.linux-x86_64/egg/openfold/utils
# copying build/lib.linux-x86_64-3.10/openfold/utils/lr_schedulers.py -> build/bdist.linux-x86_64/egg/openfold/utils
# copying build/lib.linux-x86_64-3.10/openfold/__init__.py -> build/bdist.linux-x86_64/egg/openfold
# creating build/bdist.linux-x86_64/egg/openfold/resources
# copying build/lib.linux-x86_64-3.10/openfold/resources/stereo_chemical_props.txt -> build/bdist.linux-x86_64/egg/openfold/resources
# copying build/lib.linux-x86_64-3.10/openfold/resources/__init__.py -> build/bdist.linux-x86_64/egg/openfold/resources
# byte-compiling build/bdist.linux-x86_64/egg/openfold/np/residue_constants.py to residue_constants.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/np/protein.py to protein.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/np/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/np/relax/relax.py to relax.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/np/relax/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/np/relax/amber_minimize.py to amber_minimize.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/np/relax/cleanup.py to cleanup.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/np/relax/utils.py to utils.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/model/primitives.py to primitives.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/model/dropout.py to dropout.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/model/embedders.py to embedders.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/model/outer_product_mean.py to outer_product_mean.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/model/triangular_multiplicative_update.py to triangular_multiplicative_update.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/model/msa.py to msa.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/model/evoformer.py to evoformer.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/model/torchscript.py to torchscript.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/model/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/model/triangular_attention.py to triangular_attention.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/model/pair_transition.py to pair_transition.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/model/structure_module.py to structure_module.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/model/heads.py to heads.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/model/template.py to template.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/model/model.py to model.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/data/data_pipeline.py to data_pipeline.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/data/tools/kalign.py to kalign.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/data/tools/hmmbuild.py to hmmbuild.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/data/tools/parse_msa_files.py to parse_msa_files.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/data/tools/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/data/tools/hhsearch.py to hhsearch.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/data/tools/hmmsearch.py to hmmsearch.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/data/tools/hhblits.py to hhblits.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/data/tools/utils.py to utils.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/data/tools/jackhmmer.py to jackhmmer.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/data/data_modules.py to data_modules.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/data/msa_pairing.py to msa_pairing.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/data/feature_pipeline.py to feature_pipeline.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/data/data_transforms_multimer.py to data_transforms_multimer.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/data/msa_identifiers.py to msa_identifiers.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/data/parsers.py to parsers.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/data/errors.py to errors.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/data/input_pipeline_multimer.py to input_pipeline_multimer.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/data/input_pipeline.py to input_pipeline.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/data/templates.py to templates.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/data/data_transforms.py to data_transforms.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/data/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/data/feature_processing_multimer.py to feature_processing_multimer.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/data/mmcif_parsing.py to mmcif_parsing.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/config.py to config.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/utils/all_atom_multimer.py to all_atom_multimer.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/utils/logger.py to logger.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/utils/checkpointing.py to checkpointing.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/utils/geometry/quat_rigid.py to quat_rigid.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/utils/geometry/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/utils/geometry/vector.py to vector.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/utils/geometry/utils.py to utils.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/utils/geometry/test_utils.py to test_utils.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/utils/geometry/rotation_matrix.py to rotation_matrix.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/utils/geometry/rigid_matrix_vector.py to rigid_matrix_vector.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/utils/script_utils.py to script_utils.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/utils/import_weights.py to import_weights.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/utils/callbacks.py to callbacks.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/utils/feats.py to feats.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/utils/rigid_utils.py to rigid_utils.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/utils/trace_utils.py to trace_utils.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/utils/tensor_utils.py to tensor_utils.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/utils/chunk_utils.py to chunk_utils.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/utils/multi_chain_permutation.py to multi_chain_permutation.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/utils/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/utils/validation_metrics.py to validation_metrics.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/utils/precision_utils.py to precision_utils.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/utils/superimposition.py to superimposition.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/utils/argparse_utils.py to argparse_utils.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/utils/kernel/attention_core.py to attention_core.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/utils/kernel/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/utils/loss.py to loss.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/utils/exponential_moving_average.py to exponential_moving_average.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/utils/lr_schedulers.py to lr_schedulers.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/__init__.py to __init__.cpython-310.pyc
# byte-compiling build/bdist.linux-x86_64/egg/openfold/resources/__init__.py to __init__.cpython-310.pyc
# creating stub loader for attn_core_inplace_cuda.cpython-310-x86_64-linux-gnu.so
# byte-compiling build/bdist.linux-x86_64/egg/attn_core_inplace_cuda.py to attn_core_inplace_cuda.cpython-310.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying openfold.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying openfold.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying openfold.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying openfold.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# writing build/bdist.linux-x86_64/egg/EGG-INFO/native_libs.txt
# zip_safe flag not set; analyzing archive contents...
# __pycache__.attn_core_inplace_cuda.cpython-310: module references __file__
# openfold.utils.__pycache__.script_utils.cpython-310: module references __file__
# creating dist
# creating 'dist/openfold-2.0.0-py3.10-linux-x86_64.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing openfold-2.0.0-py3.10-linux-x86_64.egg
# creating /cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/lib/python3.10/site-packages/openfold-2.0.0-py3.10-linux-x86_64.egg
# Extracting openfold-2.0.0-py3.10-linux-x86_64.egg to /cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/lib/python3.10/site-packages
# Adding openfold 2.0.0 to easy-install.pth file
#
# Installed /cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/lib/python3.10/site-packages/openfold-2.0.0-py3.10-linux-x86_64.egg
# Processing dependencies for openfold==2.0.0
# Finished processing dependencies for openfold==2.0.0
# (openfold_env)
# (openfold_env)
# (openfold_env)
# (openfold_env)
# (openfold_env)
# To make your changes take effect please reactivate your environment
# (openfold_env)
# (openfold_env)
# (openfold_env)
# To make your changes take effect please reactivate your environment
# (openfold_env)
# (miniconda3)

# %%
# 5. Download parameters
conda activate openfold_env
scripts/download_alphafold_params.sh openfold/resources
conda deactivate
# Out:
# (miniconda3)
# WARNING: overwriting environment variables set in the machine
# overwriting variable ['CUTLASS_PATH']
# (openfold_env)
#
# 06/21 15:28:45 [NOTICE] Downloading 1 item(s)
#  *** Download Progress Summary as of Fri Jun 21 15:29:46 2024 ***              m48s]
# ===============================================================================
# [#63ac61 1.8GiB/5.2GiB(35%) CN:1 DL:28MiB ETA:2m1s]
# FILE: openfold/resources/params/alphafold_params_2022-12-06.tar
# -------------------------------------------------------------------------------
#
#  *** Download Progress Summary as of Fri Jun 21 15:30:47 2024 ***              3s]mm
# ===============================================================================
# [#63ac61 3.6GiB/5.2GiB(69%) CN:1 DL:38MiB ETA:42s]
# FILE: openfold/resources/params/alphafold_params_2022-12-06.tar
# -------------------------------------------------------------------------------
#
#  *** Download Progress Summary as of Fri Jun 21 15:31:48 2024 ***              s]m
# ===============================================================================
# [#63ac61 5.0GiB/5.2GiB(97%) CN:1 DL:23MiB ETA:6s]
# FILE: openfold/resources/params/alphafold_params_2022-12-06.tar
# -------------------------------------------------------------------------------
#
# [#63ac61 5.1GiB/5.2GiB(99%) CN:1 DL:28MiB]0m]
# 06/21 15:31:52 [NOTICE] Download complete: openfold/resources/params/alphafold_params_2022-12-06.tar
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 63ac61|OK  |    28MiB/s|openfold/resources/params/alphafold_params_2022-12-06.tar
#
# Status Legend:
# (OK):download completed.
# params_model_1.npz
# params_model_2.npz
# params_model_3.npz
# params_model_4.npz
# params_model_5.npz
# params_model_1_ptm.npz
# params_model_2_ptm.npz
# params_model_3_ptm.npz
# params_model_4_ptm.npz
# params_model_5_ptm.npz
# params_model_1_multimer_v3.npz
# params_model_2_multimer_v3.npz
# params_model_3_multimer_v3.npz
# params_model_4_multimer_v3.npz
# params_model_5_multimer_v3.npz
# LICENSE
# (openfold_env)
# (miniconda3)

# %%
echo 'Model params as downloaded by https://github.com/aqlaboratory/openfold/blob/main/scripts/download_alphafold_params.sh'
md5sum openfold/resources/params/*
echo 'Local params:'
md5sum /cluster/project/alphafold/params/*
# Out:
# Model params as downloaded by https://github.com/aqlaboratory/openfold/blob/main/scripts/download_alphafold_params.sh
# (miniconda3)
# 2ab724713fdaf49e4523c4503bfd068d  openfold/resources/params/LICENSE
# fddffd89cff499afcd171f31df5b48ca  openfold/resources/params/params_model_1_multimer_v3.npz
# e2c73bf20ad82630d1cc4589b9e537ea  openfold/resources/params/params_model_1.npz
# dfca7cd972028fc6adcc0c8995857a2a  openfold/resources/params/params_model_1_ptm.npz
# 2b364df609bac5a9461e44d118426b73  openfold/resources/params/params_model_2_multimer_v3.npz
# ec0ff5b4f6942c42fc35f50342043565  openfold/resources/params/params_model_2.npz
# edb0729d11e83734b820c348c5ffe42a  openfold/resources/params/params_model_2_ptm.npz
# 4f9bc7fd9b66f0835c99ae1295f7100b  openfold/resources/params/params_model_3_multimer_v3.npz
# 78ba15ee79b038aefe37d9570c277dd7  openfold/resources/params/params_model_3.npz
# d5f286c0349708c045a0ee8090ad5a8d  openfold/resources/params/params_model_3_ptm.npz
# f7d33665caf72d3fd3a94baae3cb16e0  openfold/resources/params/params_model_4_multimer_v3.npz
# dd58c0b247a19dbbc174e939251c956d  openfold/resources/params/params_model_4.npz
# 0fcae9b2e9662dea95658959fd1522ed  openfold/resources/params/params_model_4_ptm.npz
# 6ebb9ef84d2f370605713011d5042da5  openfold/resources/params/params_model_5_multimer_v3.npz
# 03a7941fbcbb75f719daf363d510ae97  openfold/resources/params/params_model_5.npz
# 099966784d3620ff56b2439d4201f4d5  openfold/resources/params/params_model_5_ptm.npz
# (miniconda3)
# Local params:
# (miniconda3)
# 2ab724713fdaf49e4523c4503bfd068d  /cluster/project/alphafold/params/LICENSE
# 014221daa5551d7f7e3ba3954685388e  /cluster/project/alphafold/params/params_model_1_multimer.npz
# 468cbe2fbc2e2963e03d144f938613c3  /cluster/project/alphafold/params/params_model_1_multimer_v2.npz
# fddffd89cff499afcd171f31df5b48ca  /cluster/project/alphafold/params/params_model_1_multimer_v3.npz
# e2c73bf20ad82630d1cc4589b9e537ea  /cluster/project/alphafold/params/params_model_1.npz
# dfca7cd972028fc6adcc0c8995857a2a  /cluster/project/alphafold/params/params_model_1_ptm.npz
# 7e584781cd7271d267799b7cdb05883d  /cluster/project/alphafold/params/params_model_2_multimer.npz
# 46d291026f195569334907b24810eeb4  /cluster/project/alphafold/params/params_model_2_multimer_v2.npz
# 2b364df609bac5a9461e44d118426b73  /cluster/project/alphafold/params/params_model_2_multimer_v3.npz
# ec0ff5b4f6942c42fc35f50342043565  /cluster/project/alphafold/params/params_model_2.npz
# edb0729d11e83734b820c348c5ffe42a  /cluster/project/alphafold/params/params_model_2_ptm.npz
# c46d18c29c0506530a858bb97b883744  /cluster/project/alphafold/params/params_model_3_multimer.npz
# 369c67d96cbfad0a0834bc580f41a09b  /cluster/project/alphafold/params/params_model_3_multimer_v2.npz
# 4f9bc7fd9b66f0835c99ae1295f7100b  /cluster/project/alphafold/params/params_model_3_multimer_v3.npz
# 78ba15ee79b038aefe37d9570c277dd7  /cluster/project/alphafold/params/params_model_3.npz
# d5f286c0349708c045a0ee8090ad5a8d  /cluster/project/alphafold/params/params_model_3_ptm.npz
# 573e03c069516c371a26b951c1852ec6  /cluster/project/alphafold/params/params_model_4_multimer.npz
# 266de424607af1c942f01785c2d7d899  /cluster/project/alphafold/params/params_model_4_multimer_v2.npz
# f7d33665caf72d3fd3a94baae3cb16e0  /cluster/project/alphafold/params/params_model_4_multimer_v3.npz
# dd58c0b247a19dbbc174e939251c956d  /cluster/project/alphafold/params/params_model_4.npz
# 0fcae9b2e9662dea95658959fd1522ed  /cluster/project/alphafold/params/params_model_4_ptm.npz
# b64ff30e83620ead05f3ffdd8bd8b3b8  /cluster/project/alphafold/params/params_model_5_multimer.npz
# 20d4981f01baaf7e763b27fea25bbdfb  /cluster/project/alphafold/params/params_model_5_multimer_v2.npz
# 6ebb9ef84d2f370605713011d5042da5  /cluster/project/alphafold/params/params_model_5_multimer_v3.npz
# 03a7941fbcbb75f719daf363d510ae97  /cluster/project/alphafold/params/params_model_5.npz
# 099966784d3620ff56b2439d4201f4d5  /cluster/project/alphafold/params/params_model_5_ptm.npz
# (miniconda3)

# %%
# 6. Run OpenFold unit tests
conda run -n openfold_env scripts/run_unit_tests.sh
# Out:
# (miniconda3)
# [2024-06-21 15:32:08,495] [INFO] [real_accelerator.py:161:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# [1/4] /cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/bin/x86_64-conda-linux-gnu-c++ -MMD -MF attention.o.d -DTORCH_EXTENSION_NAME=evoformer_attn -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -I/cluster/work/beltrao/jjaenes/24.06.10_af2genomics/software/openfold/cutlass/include -I/cluster/work/beltrao/jjaenes/24.06.10_af2genomics/software/openfold/cutlass/tools/util/include -isystem /cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/lib/python3.10/site-packages/torch/include -isystem /cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/lib/python3.10/site-packages/torch/include/torch/csrc/api/include -isystem /cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/lib/python3.10/site-packages/torch/include/TH -isystem /cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/lib/python3.10/site-packages/torch/include/THC -isystem /cluster/software/stacks/2024-05/spack/opt/spack/linux-ubuntu22.04-x86_64_v3/gcc-13.2.0/cuda-12.2.1-fv6yilrnidoe35nh24iszjkf63bihikt/include -isystem /cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/include/python3.10 -D_GLIBCXX_USE_CXX11_ABI=0 -fPIC -std=c++17 -O3 -std=c++17 -g -Wno-reorder -DBF16_AVAILABLE -c /cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/lib/python3.10/site-packages/deepspeed/ops/csrc/deepspeed4science/evoformer_attn/attention.cpp -o attention.o
# [2/4] /cluster/software/stacks/2024-05/spack/opt/spack/linux-ubuntu22.04-x86_64_v3/gcc-13.2.0/cuda-12.2.1-fv6yilrnidoe35nh24iszjkf63bihikt/bin/nvcc  -ccbin /cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/bin/x86_64-conda-linux-gnu-cc -DTORCH_EXTENSION_NAME=evoformer_attn -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -I/cluster/work/beltrao/jjaenes/24.06.10_af2genomics/software/openfold/cutlass/include -I/cluster/work/beltrao/jjaenes/24.06.10_af2genomics/software/openfold/cutlass/tools/util/include -isystem /cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/lib/python3.10/site-packages/torch/include -isystem /cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/lib/python3.10/site-packages/torch/include/torch/csrc/api/include -isystem /cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/lib/python3.10/site-packages/torch/include/TH -isystem /cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/lib/python3.10/site-packages/torch/include/THC -isystem /cluster/software/stacks/2024-05/spack/opt/spack/linux-ubuntu22.04-x86_64_v3/gcc-13.2.0/cuda-12.2.1-fv6yilrnidoe35nh24iszjkf63bihikt/include -isystem /cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/include/python3.10 -D_GLIBCXX_USE_CXX11_ABI=0 -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr -gencode=arch=compute_89,code=compute_89 -gencode=arch=compute_89,code=sm_89 --compiler-options '-fPIC' -O3 --use_fast_math -std=c++17 -U__CUDA_NO_HALF_OPERATORS__ -U__CUDA_NO_HALF_CONVERSIONS__ -U__CUDA_NO_HALF2_OPERATORS__ -gencode=arch=compute_89,code=sm_89 -gencode=arch=compute_89,code=compute_89 -DGPU_ARCH=89 -DBF16_AVAILABLE -U__CUDA_NO_BFLOAT16_OPERATORS__ -U__CUDA_NO_BFLOAT162_OPERATORS__ -c /cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/lib/python3.10/site-packages/deepspeed/ops/csrc/deepspeed4science/evoformer_attn/attention_cu.cu -o attention_cu.cuda.o
# [3/4] /cluster/software/stacks/2024-05/spack/opt/spack/linux-ubuntu22.04-x86_64_v3/gcc-13.2.0/cuda-12.2.1-fv6yilrnidoe35nh24iszjkf63bihikt/bin/nvcc  -ccbin /cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/bin/x86_64-conda-linux-gnu-cc -DTORCH_EXTENSION_NAME=evoformer_attn -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -I/cluster/work/beltrao/jjaenes/24.06.10_af2genomics/software/openfold/cutlass/include -I/cluster/work/beltrao/jjaenes/24.06.10_af2genomics/software/openfold/cutlass/tools/util/include -isystem /cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/lib/python3.10/site-packages/torch/include -isystem /cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/lib/python3.10/site-packages/torch/include/torch/csrc/api/include -isystem /cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/lib/python3.10/site-packages/torch/include/TH -isystem /cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/lib/python3.10/site-packages/torch/include/THC -isystem /cluster/software/stacks/2024-05/spack/opt/spack/linux-ubuntu22.04-x86_64_v3/gcc-13.2.0/cuda-12.2.1-fv6yilrnidoe35nh24iszjkf63bihikt/include -isystem /cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/include/python3.10 -D_GLIBCXX_USE_CXX11_ABI=0 -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr -gencode=arch=compute_89,code=compute_89 -gencode=arch=compute_89,code=sm_89 --compiler-options '-fPIC' -O3 --use_fast_math -std=c++17 -U__CUDA_NO_HALF_OPERATORS__ -U__CUDA_NO_HALF_CONVERSIONS__ -U__CUDA_NO_HALF2_OPERATORS__ -gencode=arch=compute_89,code=sm_89 -gencode=arch=compute_89,code=compute_89 -DGPU_ARCH=89 -DBF16_AVAILABLE -U__CUDA_NO_BFLOAT16_OPERATORS__ -U__CUDA_NO_BFLOAT162_OPERATORS__ -c /cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/lib/python3.10/site-packages/deepspeed/ops/csrc/deepspeed4science/evoformer_attn/attention_back.cu -o attention_back.cuda.o
# [4/4] /cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/bin/x86_64-conda-linux-gnu-c++ attention.o attention_back.cuda.o attention_cu.cuda.o -shared -lcurand -L/cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/lib/python3.10/site-packages/torch/lib -lc10 -lc10_cuda -ltorch_cpu -ltorch_cuda -ltorch -ltorch_python -L/cluster/software/stacks/2024-05/spack/opt/spack/linux-ubuntu22.04-x86_64_v3/gcc-13.2.0/cuda-12.2.1-fv6yilrnidoe35nh24iszjkf63bihikt/lib64 -lcudart -o evoformer_attn.so
# Time to load evoformer_attn op: 231.49393105506897 seconds
#
# Test(s) failed. Make sure you've installed all Python dependencies.
#
# WARNING: overwriting environment variables set in the machine
# overwriting variable ['CUTLASS_PATH']
# s.................Using /cluster/home/jjaenes/.cache/torch_extensions/py310_cu121 as PyTorch extensions root...
# Detected CUDA files, patching ldflags
# Emitting ninja build file /cluster/home/jjaenes/.cache/torch_extensions/py310_cu121/evoformer_attn/build.ninja...
# Building extension module evoformer_attn...
# Using envvar MAX_JOBS (10) as the number of workers...
# Loading extension module evoformer_attn...
# ..F.........s...s.sss.ss.....sssssssss.sss....ssssss..s.s.s.ss.s......s.s..ss...ss.s.s....s........
# ======================================================================
# FAIL: test_compare_model (tests.test_deepspeed_evo_attention.TestDeepSpeedKernel)
# Run full model with and without using DeepSpeed Evoformer attention kernel
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/cluster/work/beltrao/jjaenes/24.06.10_af2genomics/software/openfold/tests/test_deepspeed_evo_attention.py", line 334, in test_compare_model
#     compare_utils.assert_mean_abs_diff_small(out_repro, out_repro_ds, eps)
#   File "/cluster/work/beltrao/jjaenes/24.06.10_af2genomics/software/openfold/tests/compare_utils.py", line 139, in assert_mean_abs_diff_small
#     _assert_abs_diff_small_base(torch.mean, expected, actual, eps)
#   File "/cluster/work/beltrao/jjaenes/24.06.10_af2genomics/software/openfold/tests/compare_utils.py", line 131, in _assert_abs_diff_small_base
#     torch.testing.assert_close(err, zero_tensor, atol=eps, rtol=rtol)
#   File "/cluster/project/beltrao/jjaenes/software/miniconda3/envs/openfold_env/lib/python3.10/site-packages/torch/testing/_comparison.py", line 1520, in assert_close
#     raise error_metas[0].to_error(msg)
# AssertionError: Scalars are not close!
#
# Expected 0.0 but got 0.23292914032936096.
# Absolute difference: 0.23292914032936096 (up to 0.2 allowed)
# Relative difference: inf (up to 1.3e-06 allowed)
#
# ----------------------------------------------------------------------
# Ran 117 tests in 252.588s
#
# FAILED (failures=1, skipped=41)
#
# (miniconda3)

# %%
# Uninstall:
#cd ..
#pwd
#rm -rf openfold
#mamba deactivate
#mamba env remove -n openfold_env -y
# Out:
# (miniconda3)
# (miniconda3)
# (miniconda3)
# (miniconda3)
# (miniconda3)
# (miniconda3)
